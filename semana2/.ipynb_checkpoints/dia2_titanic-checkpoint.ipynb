# %% [markdown]
# # Semana 2 - Día 2: Cargar y explorar datos reales
#
# Hoy cargaré un dataset real desde un archivo CSV
# y lo exploraré con las herramientas de pandas.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../datasets/titanic.csv")
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    str
#  4   Sex          418 non-null    str
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    str
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     str
#  11  Embarked     418 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 39.3 KB
# None

# %% [markdown]
# ## Ejercicio Día 2 - Explorando el Titanic
#
# Con el dataset cargado responde:
#
# 1. ¿Cuántas filas y columnas tiene el dataset?
# 2. ¿Qué columnas tienen valores nulos? ¿Cuántos nulos tiene cada una?
# 3. Usa .describe() en las columnas numéricas - ¿qué información te da?
# 4. ¿Cuál es la edad promedio de los pasajeros?
# 5. ¿Cuál es el precio de ticket (Fare) más caro y más barato?
# 6. Muestra solo las columnas "Name" y "Age" usando doble corchete df[["col1","col2"]]

# %%
#¿Cuántas filas y columnas tiene el dataset?
print(df.shape)
#Tiene 418 filas y 12 columnas
# Out:
# (418, 12)

# %%
#¿Qué columnas tienen valores nulos? ¿Cuántos nulos tiene cada una?
print(df.isnull().sum())

#Age tiene 86 nulls y Cabin 327 nulls
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# Usa .describe() en las columnas numéricas - ¿qué información te da
print(df.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
# ¿Cuál es la edad promedio de los pasajeros?

print(np.mean(df["Age"]))
# Out:
# 30.272590361445783

# %%
#¿Cuál es el precio de ticket (Fare) más caro y más barato?
print("Precio ticket maximo: ", np.max(df["Fare"]), "| Precio ticket minimo: ", np.min(df["Fare"]))
# Out:
# Precio ticket maximo:  512.3292 | Precio ticket minimo:  0.0

# %%
print(df[["Name","Age"]])
# Out:
#                                              Name   Age
# 0                                Kelly, Mr. James  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0
# 2                       Myles, Mr. Thomas Francis  62.0
# 3                                Wirz, Mr. Albert  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# ..                                            ...   ...
# 413                            Spector, Mr. Woolf   NaN
# 414                  Oliva y Ocana, Dona. Fermina  39.0
# 415                  Saether, Mr. Simon Sivertsen  38.5
# 416                           Ware, Mr. Frederick   NaN
# 417                      Peter, Master. Michael J   NaN
#
# [418 rows x 2 columns]
